# %%
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
from dotenv import load_dotenv

from backend.graphs.pdf_graph import create_pdf_graph
from backend.graphs.prompt_graph import create_prompt_graph
from backend.graphs.summarizing_graph import create_summarizing_graph
from backend.graphs.scriptwriting_graph import create_scriptwriting_graph
from backend.graphs.arxiv_graph import create_arxiv_graph
from backend.graphs.interview_graph import create_interview_graph

load_dotenv()

prompt_graph = create_prompt_graph()
display(
    Image(
        prompt_graph.get_graph(xray=5).draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
pdf_graph = create_pdf_graph()
display(
    Image(
        pdf_graph.get_graph(xray=5).draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
print(prompt_graph.get_graph(xray=5).draw_mermaid())
# Out:
# %%{init: {'flowchart': {'curve': 'linear'}}}%%
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	research_graph_create_analysts(create_analysts)
# 	research_graph_conduct_interview___start__(<p>__start__</p>)
# 	research_graph_conduct_interview_ask_question(ask_question)
# 	research_graph_conduct_interview_search_web(search_web)
# 	research_graph_conduct_interview_search_wikipedia(search_wikipedia)
# 	research_graph_conduct_interview_search_arxiv(search_arxiv)
# 	research_graph_conduct_interview_answer_question(answer_question)
# 	research_graph_conduct_interview_save_interview(save_interview)
# 	research_graph_conduct_interview_write_section(write_section)
# 	research_graph_write_report(write_report)
# 	research_graph_write_introduction(write_introduction)
# 	research_graph_write_conclusion(write_conclusion)
# 	research_graph_finalize_report(finalize_report)
# 	report_reading(report_reading)
# 	scriptwriting_graph_planning_node(planning_node)
# 	scriptwriting_graph_writing_node(writing_node)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> research_graph_create_analysts;
# 	report_reading --> scriptwriting_graph_planning_node;
# 	research_graph_finalize_report --> report_reading;
# 	scriptwriting_graph_writing_node --> __end__;
# 	subgraph research_graph
# 	research_graph_conduct_interview_write_section --> research_graph_write_conclusion;
# 	research_graph_conduct_interview_write_section --> research_graph_write_introduction;
# 	research_graph_conduct_interview_write_section --> research_graph_write_report;
# 	research_graph_write_conclusion --> research_graph_finalize_report;
# 	research_graph_write_introduction --> research_graph_finalize_report;
# 	research_graph_write_report --> research_graph_finalize_report;
# 	research_graph_create_analysts -.-> research_graph_conduct_interview___start__;
# 	subgraph conduct_interview
# 	research_graph_conduct_interview___start__ --> research_graph_conduct_interview_ask_question;
# 	research_graph_conduct_interview_ask_question --> research_graph_conduct_interview_search_arxiv;
# 	research_graph_conduct_interview_ask_question --> research_graph_conduct_interview_search_web;
# 	research_graph_conduct_interview_ask_question --> research_graph_conduct_interview_search_wikipedia;
# 	research_graph_conduct_interview_save_interview --> research_graph_conduct_interview_write_section;
# 	research_graph_conduct_interview_search_arxiv --> research_graph_conduct_interview_answer_question;
# 	research_graph_conduct_interview_search_web --> research_graph_conduct_interview_answer_question;
# 	research_graph_conduct_interview_search_wikipedia --> research_graph_conduct_interview_answer_question;
# 	research_graph_conduct_interview_answer_question -.-> research_graph_conduct_interview_ask_question;
# 	research_graph_conduct_interview_answer_question -.-> research_graph_conduct_interview_save_interview;
# 	end
# 	end
# 	subgraph scriptwriting_graph
# 	scriptwriting_graph_planning_node --> scriptwriting_graph_writing_node;
# 	end
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
pdf_graph = create_pdf_graph()
display(
    Image(
        summarizing_graph.get_graph(xray=5).draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)
